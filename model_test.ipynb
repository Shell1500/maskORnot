# %% [markdown]
# Connecting to drive and moving into the model directory

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
os.chdir('drive/My Drive/face_mask')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Installing & Importing Fastbook

# %%
# !pip install -Uqq fastbook
import fastbook
from fastbook import *

# %% [markdown]
# Loading in the already made model

# %%
learn_inf = load_learner('export.pkl')

# %% [markdown]
# Testing the model with an image in the path

# %%
learn_inf.predict('45x45.jpg')
# Out:
# ('without_mask', tensor(1), tensor([2.1908e-14, 1.0000e+00]))
